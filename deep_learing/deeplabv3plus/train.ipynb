# %%
# %matplotlib inline

import os
import time
import math
import glob
import shutil
import numpy as np
#import pandas as pd
import matplotlib.pyplot as plt
import h5py

from pathlib import Path
from torch.utils.data import Dataset, DataLoader, sampler
from torch.cuda.amp import GradScaler, autocast
from PIL import Image

import torch
from torch.nn import functional as F
from torch.autograd import Variable

##############################
from models import deeplab_resnet_hyper
from models import deeplab_xception
from datasets import datasets

from utils import manager as mgr
from utils import metrics
from utils import losses
from utils import log
from utils import img_utils
##############################

nr_classes = 4
nr_channels = 7
#exp_name = 'deeplab_df_std_f01'
exp_name = 'deeplab_std_resnet_cr32'
DEVICE = "cuda:1"
#WEIGHTS_PATH = 'weights_f01/'
WEIGHTS_PATH = 'weights/' + exp_name + '/'

backbone = 'resnet'#'xception'#'resnet'

# set device
#device = torch.device(DEVICE if torch.cuda.is_available() else "cpu")
device = "cuda:1"
device_nr = int(device[-1])
#device = "cpu"
print(device)

# batch size (256) 56, (512) 15
batch_size = 72
split={'train':0.7, 'val':0.1, 'test':0.2}
num_workers = 4
pin_memory = True

LR = 0.001
LR_DECAY = 0.995
DECAY_EVERY_N_EPOCHS = 1
N_EPOCHS = 25
start_epoch = 1

cr = 32
dsize = 256
ddepth = 3
os = 16
# Out:
# cuda:1

# %%
## Creating the dataset
path_dataset = "/home/philipp/Data/dataset_256_df_177.h5"
#path_dataset = "/home/philipp/Data/dataset_ext_256_df_177.h5"
dataset = datasets.ForestDataset(path_dataset, ground_truth='ground_truth_std')

if dataset[0][0].shape[1] == 256:
    chunk_size = 1000
else:
    chunk_size = 0

# shuffle and split
train_sampler, val_sampler, test_sampler = dataset.get_sampler(split=split, \
                shuffle_dataset=True, random_seed=399, chunk_size=chunk_size, fold=0)

# dataloader
train_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=train_sampler, num_workers=num_workers, pin_memory=pin_memory)
val_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=val_sampler, num_workers=num_workers, pin_memory=pin_memory)
test_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=test_sampler, num_workers=num_workers, pin_memory=pin_memory)
print(len(dataset))
print(len(train_sampler.indices))
print(len(val_sampler.indices))
print(len(test_sampler.indices))
# Out:
# 42716
# 29908
# 4268
# 8540

# %%
# show examples
#img_utils.view_sample(train_dl, 10)

# %%
#############
#   train
#############
def train(model, trn_loader, optimizer, criterion, epoch):
    
    model.train()
    step = 0
    metric = {'loss': 0.0, \
              'acc_all':0.0, \
              'acc_mean':0.0, \
              'jacc':0.0, \
              'dice':0.0}

    for idx, data in enumerate(trn_loader):
        x = Variable(data[0].to(device))
        y = Variable(data[1].to(device))
        step += 1
        
        # forward pass
        optimizer.zero_grad()
        output = model(x)
        loss = criterion(output, y)
        
        # backward pass
        loss.backward()
        # update weights
        optimizer.step()

        # calculate predictions
        pred = mgr.get_predictions(output)
        
        # calculate metrics for the batch
        overall_acc, avg_per_class_acc, avg_jacc, avg_dice = metrics.eval_metrics(y, pred, num_classes=nr_classes, device=device)
        # update running metrics
        for i, m in zip(metric, [loss, overall_acc, avg_per_class_acc, avg_jacc, avg_dice]):
            metric[i] += m*trn_loader.batch_size
        
        # print metrics to console
        if step % 100 == 0:
            print('Step: {}  Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
                  .format(step, loss, overall_acc, avg_per_class_acc, avg_jacc, avg_dice))
    
    # calculate metrics for the epoch      
    for i in metric:
        metric[i] /= len(train_sampler.indices)
                    
    return metric

#############
#   test
#############
def test(model, test_loader, criterion, epoch=1):
    
    model.eval()
    step = 0
    metric = {'loss': 0.0, \
              'acc_all':0.0, \
              'acc_mean':0.0, \
              'jacc':0.0, \
              'dice':0.0}
    
    for data, target in test_loader:
        x = Variable(data.to(device))
        y = Variable(target.to(device))
        step += 1
        
        # forward pass
        with torch.no_grad():
            output = model(x)
            loss = criterion(output, y)
            #test_loss += criterion(output, y).data.item()
            
        # calculate predictions    
        pred = mgr.get_predictions(output)
        
        # calculate metrics for the batch
        overall_acc, avg_per_class_acc, avg_jacc, avg_dice = metrics.eval_metrics(y, pred, num_classes=nr_classes, device=device)
        # update running metrics
        for i, m in zip(metric, [loss, overall_acc, avg_per_class_acc, avg_jacc, avg_dice]):
            metric[i] += m*test_loader.batch_size
            
        # print metrics to console
        if step % 100 == 0:
            print('Step: {}  Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
                  .format(step, loss, overall_acc, avg_per_class_acc, avg_jacc, avg_dice))
        
    # calculate metrics for the epoch
    for i in metric:
        metric[i] /= len(val_sampler.indices)
                    
    return metric

# %%
# Network definition
if backbone == 'xception':
    model = deeplab_xception.DeepLabv3_plus(nInputChannels=nr_channels, \
                                            n_classes=nr_classes, os=os, pretrained=False)
elif backbone == 'resnet':
    model = deeplab_resnet_hyper.DeepLabv3_plus(nInputChannels=nr_channels, \
                                                n_classes=nr_classes, os=os, \
                                                pretrained=False, \
                                                cr=cr, \
                                                dsize=dsize, \
                                                ddepth=ddepth)
else:
    raise NotImplementedError

try:
    start_epoch = mgr.load_weights(model, WEIGHTS_PATH + 'latest.pth')
    #load_weights(model, WEIGHTS_PATH+'latest_5d.pt')
    print("weights loaded")
except:
    #model.apply(weights_init)
    #os.makedirs(WEIGHTS_PATH, exist_ok=True) 
    print("no weights found")

torch.cuda.set_device(device=device_nr)
model.cuda()
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
#optimizer = optim.SGD(net.parameters(), lr=p['lr'], momentum=p['momentum'], weight_decay=p['wd'])
criterion = losses.Dice_Loss()
#criterion = torch.nn.CrossEntropyLoss()

#    
#if resume_epoch == 0:
#    print("Training deeplabv3+ from scratch...")
#else:
#    print("Initializing weights from: {}...".format(
#        os.path.join(save_dir, 'models', modelName + '_epoch-' + str(resume_epoch - 1) + '.pth')))
#    net.load_state_dict(
#        torch.load(os.path.join(save_dir, 'models', modelName + '_epoch-' + str(resume_epoch - 1) + '.pth'),
#                   map_location=lambda storage, loc: storage)) # Load all tensors onto the CPU
# Out:
# Constructing DeepLabv3+ model...
# Number of classes: 4
# Output stride: 16
# Number of Input Channels: 7
# loading weights 'weights/deeplab_std_resnet_cr32/latest.pth'
# loaded weights (lastEpoch 14, loss 0.1510310173034668, error 0.8822174072265625)
# weights loaded

# %%
## Initialising logging
logging = log.Log(exp_name)
start_epoch = 1
logging.start_log(LR, N_EPOCHS)
logging.start_csv()

for epoch in range(start_epoch, N_EPOCHS+1):
    since = time.time()
    
    print('-' * 10)
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)

    ### Train ###
    metric = train(model, train_dl, optimizer, criterion, epoch)
    # print metrics to console
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)
    print('Train Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Train Time {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'train')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'train')
    
    ### Test ###
    metric = test(model, val_dl, criterion, epoch) 
    print('-' * 10)
    print('Val Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Total Time {:.0f}m {:.0f}s\n'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'val')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'val')
    
    ### Checkpoint ###    
    mgr.save_weights(model, epoch, metric['loss'], metric['acc_all'], WEIGHTS_PATH)

    ### Adjust Lr ###
    mgr.adjust_learning_rate(LR, LR_DECAY, optimizer, epoch, DECAY_EVERY_N_EPOCHS)
# Out:
# ----------
# Epoch 1/25
# ----------
# /home/philipp/Software/minconda3/envs/pytorch/lib/python3.8/site-packages/torch/nn/functional.py:3325: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Step: 100  Loss: 0.2050  Acc all: 0.8365  Acc mean: 0.7690  IoU: 0.6666  Dice: 0.7950
# Step: 200  Loss: 0.1601  Acc all: 0.8729  Acc mean: 0.8232  IoU: 0.7313  Dice: 0.8400
# Step: 300  Loss: 0.1484  Acc all: 0.8541  Acc mean: 0.8635  IoU: 0.7561  Dice: 0.8516
# Step: 400  Loss: 0.2061  Acc all: 0.8124  Acc mean: 0.7939  IoU: 0.6835  Dice: 0.7941
# Epoch 1/25
# ----------
# Train Loss: 0.1611  Acc all: 0.8660  Acc mean: 0.8297  IoU: 0.7393  Dice: 0.8404
# ----------
# Train Time 7m 6s
# ----------
# Val Loss: 0.1623  Acc all: 0.8675  Acc mean: 0.8491  IoU: 0.7494  Dice: 0.8499
# ----------
# Total Time 7m 35s
#
# ----------
# Epoch 2/25
# ----------
# Step: 100  Loss: 0.1424  Acc all: 0.8805  Acc mean: 0.8408  IoU: 0.7626  Dice: 0.8577
# Step: 200  Loss: 0.1893  Acc all: 0.8479  Acc mean: 0.8242  IoU: 0.6997  Dice: 0.8107
# Step: 300  Loss: 0.1193  Acc all: 0.8850  Acc mean: 0.8587  IoU: 0.7962  Dice: 0.8808
# Step: 400  Loss: 0.2188  Acc all: 0.8158  Acc mean: 0.7681  IoU: 0.6530  Dice: 0.7812
# Epoch 2/25
# ----------
# Train Loss: 0.1587  Acc all: 0.8687  Acc mean: 0.8314  IoU: 0.7425  Dice: 0.8428
# ----------
# Train Time 7m 1s
# ----------
# Val Loss: 0.1616  Acc all: 0.8763  Acc mean: 0.8377  IoU: 0.7511  Dice: 0.8506
# ----------
# Total Time 7m 31s
#
# ----------
# Epoch 3/25
# ----------
# Step: 100  Loss: 0.1492  Acc all: 0.8517  Acc mean: 0.8457  IoU: 0.7571  Dice: 0.8509
# Step: 200  Loss: 0.1537  Acc all: 0.8772  Acc mean: 0.8337  IoU: 0.7507  Dice: 0.8464
# Step: 300  Loss: 0.2541  Acc all: 0.8085  Acc mean: 0.7064  IoU: 0.6109  Dice: 0.7459
# Step: 400  Loss: 0.1612  Acc all: 0.8386  Acc mean: 0.8336  IoU: 0.7420  Dice: 0.8389
# Epoch 3/25
# ----------
# Train Loss: 0.1566  Acc all: 0.8700  Acc mean: 0.8341  IoU: 0.7454  Dice: 0.8449
# ----------
# Train Time 6m 54s
# ----------
# Val Loss: 0.1568  Acc all: 0.8812  Acc mean: 0.8390  IoU: 0.7578  Dice: 0.8554
# ----------
# Epoch 7/25
# ----------
# Train Loss: 0.1535  Acc all: 0.8733  Acc mean: 0.8364  IoU: 0.7494  Dice: 0.8480
# ----------
# Train Time 6m 50s
# ----------
# Val Loss: 0.1664  Acc all: 0.8810  Acc mean: 0.8229  IoU: 0.7469  Dice: 0.8458
# ----------
# Total Time 7m 20s
#
# ----------
# Epoch 8/25
# ----------
# Step: 100  Loss: 0.1299  Acc all: 0.8890  Acc mean: 0.8643  IoU: 0.7820  Dice: 0.8701
# Step: 200  Loss: 0.1469  Acc all: 0.8839  Acc mean: 0.8636  IoU: 0.7600  Dice: 0.8531
# Step: 300  Loss: 0.1471  Acc all: 0.8827  Acc mean: 0.8505  IoU: 0.7591  Dice: 0.8529
# Step: 400  Loss: 0.1550  Acc all: 0.8725  Acc mean: 0.8257  IoU: 0.7405  Dice: 0.8451
# Epoch 8/25
# ----------
# Train Loss: 0.1544  Acc all: 0.8727  Acc mean: 0.8360  IoU: 0.7483  Dice: 0.8471
# ----------
# Train Time 6m 55s
# ----------
# Val Loss: 0.1559  Acc all: 0.8801  Acc mean: 0.8437  IoU: 0.7590  Dice: 0.8563
# ----------
# Total Time 7m 27s
#
# ----------
# Epoch 9/25
# ----------
# Step: 100  Loss: 0.1548  Acc all: 0.8602  Acc mean: 0.8472  IoU: 0.7480  Dice: 0.8452
# Step: 200  Loss: 0.1509  Acc all: 0.8679  Acc mean: 0.8207  IoU: 0.7502  Dice: 0.8491
# Step: 300  Loss: 0.1260  Acc all: 0.8772  Acc mean: 0.9031  IoU: 0.7905  Dice: 0.8740
# Step: 400  Loss: 0.1305  Acc all: 0.8755  Acc mean: 0.8543  IoU: 0.7806  Dice: 0.8695
# Epoch 9/25
# ----------
# Train Loss: 0.1497  Acc all: 0.8753  Acc mean: 0.8390  IoU: 0.7546  Dice: 0.8518
# ----------
# Train Time 6m 52s
# ----------
# Val Loss: 0.1524  Acc all: 0.8853  Acc mean: 0.8420  IoU: 0.7636  Dice: 0.8599
# ----------
# Total Time 7m 22s
#
# ----------
# Epoch 10/25
# ----------
# Step: 100  Loss: 0.0937  Acc all: 0.9256  Acc mean: 0.8900  IoU: 0.8333  Dice: 0.9063
# Step: 200  Loss: 0.1385  Acc all: 0.8828  Acc mean: 0.8439  IoU: 0.7712  Dice: 0.8615
# Step: 300  Loss: 0.1048  Acc all: 0.8965  Acc mean: 0.8744  IoU: 0.8180  Dice: 0.8952
# Step: 400  Loss: 0.1398  Acc all: 0.8814  Acc mean: 0.8533  IoU: 0.7641  Dice: 0.8602
# Epoch 10/25
# ----------
# Train Loss: 0.1498  Acc all: 0.8768  Acc mean: 0.8391  IoU: 0.7544  Dice: 0.8517
# ----------
# Train Time 7m 2s
# ----------
# Val Loss: 0.1563  Acc all: 0.8832  Acc mean: 0.8390  IoU: 0.7583  Dice: 0.8559
# ----------
# Total Time 7m 33s
#
# ----------
# Epoch 11/25
# ----------
# Step: 100  Loss: 0.2084  Acc all: 0.8406  Acc mean: 0.7609  IoU: 0.6597  Dice: 0.7917
# Step: 400  Loss: 0.1293  Acc all: 0.8855  Acc mean: 0.8565  IoU: 0.7801  Dice: 0.8707
# Epoch 18/25
# ----------
# Train Loss: 0.1412  Acc all: 0.8829  Acc mean: 0.8482  IoU: 0.7663  Dice: 0.8603
# ----------
# Train Time 6m 49s
# ----------
# Val Loss: 0.1559  Acc all: 0.8828  Acc mean: 0.8412  IoU: 0.7591  Dice: 0.8563
# ----------
# Total Time 7m 16s
#
# ----------
# Epoch 19/25
# ----------
# Step: 100  Loss: 0.1352  Acc all: 0.9061  Acc mean: 0.8547  IoU: 0.7806  Dice: 0.8648
# Step: 200  Loss: 0.1477  Acc all: 0.8753  Acc mean: 0.8300  IoU: 0.7627  Dice: 0.8523
# Step: 300  Loss: 0.1331  Acc all: 0.8832  Acc mean: 0.8645  IoU: 0.7719  Dice: 0.8670
# Step: 400  Loss: 0.1308  Acc all: 0.9057  Acc mean: 0.8493  IoU: 0.7826  Dice: 0.8692
# Epoch 19/25
# ----------
# Train Loss: 0.1429  Acc all: 0.8826  Acc mean: 0.8474  IoU: 0.7639  Dice: 0.8586
# ----------
# Train Time 6m 50s
# ----------
# Val Loss: 0.1529  Acc all: 0.8852  Acc mean: 0.8456  IoU: 0.7638  Dice: 0.8593
# ----------
# Total Time 7m 19s
#
# ----------
# Epoch 20/25
# ----------
# Step: 100  Loss: 0.1181  Acc all: 0.8763  Acc mean: 0.8678  IoU: 0.7936  Dice: 0.8819
# Step: 200  Loss: 0.1958  Acc all: 0.8330  Acc mean: 0.7808  IoU: 0.6890  Dice: 0.8043
# Step: 300  Loss: 0.1211  Acc all: 0.9051  Acc mean: 0.8729  IoU: 0.7956  Dice: 0.8789
# Step: 400  Loss: 0.1215  Acc all: 0.8891  Acc mean: 0.8780  IoU: 0.7940  Dice: 0.8785
# Epoch 20/25
# ----------
# Train Loss: 0.1441  Acc all: 0.8819  Acc mean: 0.8456  IoU: 0.7624  Dice: 0.8574
# ----------
# Train Time 6m 50s
# ----------
# Val Loss: 0.1575  Acc all: 0.8822  Acc mean: 0.8332  IoU: 0.7572  Dice: 0.8547
# ----------
# Total Time 7m 17s
#
# ----------
# Epoch 21/25
# ----------
# Step: 100  Loss: 0.1650  Acc all: 0.8755  Acc mean: 0.8138  IoU: 0.7301  Dice: 0.8350
# Step: 200  Loss: 0.1381  Acc all: 0.8911  Acc mean: 0.8645  IoU: 0.7730  Dice: 0.8620
# Step: 300  Loss: 0.1770  Acc all: 0.8481  Acc mean: 0.8409  IoU: 0.7168  Dice: 0.8230
# Step: 400  Loss: 0.1533  Acc all: 0.8553  Acc mean: 0.8336  IoU: 0.7482  Dice: 0.8467
# Epoch 21/25
# ----------
# Train Loss: 0.1396  Acc all: 0.8846  Acc mean: 0.8507  IoU: 0.7686  Dice: 0.8619
# ----------
# Train Time 6m 58s
# ----------
# Val Loss: 0.1512  Acc all: 0.8849  Acc mean: 0.8460  IoU: 0.7659  Dice: 0.8610
# ----------
# Total Time 7m 27s
#
# ----------
# Epoch 22/25
# Train Loss: 0.1337  Acc all: 0.8901  Acc mean: 0.8559  IoU: 0.7768  Dice: 0.8678
# ----------
# Train Time 6m 50s
# ----------
# Val Loss: 0.1517  Acc all: 0.8806  Acc mean: 0.8498  IoU: 0.7646  Dice: 0.8605
# ----------
# Total Time 7m 17s

# %%
# cr 64

# %%
torch.cuda.empty_cache()

nr_classes = 4
nr_channels = 7
exp_name = 'deeplab_std_resnet_cr64'
WEIGHTS_PATH = 'weights/' + exp_name + '/'
N_EPOCHS = 25
start_epoch = 1
backbone = 'resnet'

cr = 64
dsize = 256
ddepth = 3
os = 16

#######################################################

## Creating the dataset
path_dataset = "/home/philipp/Data/dataset_256_df_177.h5"
#path_dataset = "/media/philipp/DATA/dataset/dataset_256_df_0.h5"
dataset = datasets.ForestDataset(path_dataset, ground_truth='ground_truth_std')

if dataset[0][0].shape[1] == 256:
    chunk_size = 1000
else:
    chunk_size = 0

# shuffle and split
train_sampler, val_sampler, test_sampler = dataset.get_sampler(split=split, \
                shuffle_dataset=True, random_seed=399, chunk_size=chunk_size)

# dataloader
train_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=train_sampler, num_workers=num_workers, pin_memory=pin_memory)
val_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=val_sampler, num_workers=num_workers, pin_memory=pin_memory)
test_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=test_sampler, num_workers=num_workers, pin_memory=pin_memory)
print(len(dataset))
print(len(train_sampler.indices))
print(len(val_sampler.indices))
print(len(test_sampler.indices))

#######################################################

# Network definition
if backbone == 'xception':
    model = deeplab_xception.DeepLabv3_plus(nInputChannels=nr_channels, \
                                            n_classes=nr_classes, os=os, pretrained=False)
elif backbone == 'resnet':
    model = deeplab_resnet_hyper.DeepLabv3_plus(nInputChannels=nr_channels, \
                                                n_classes=nr_classes, os=os, \
                                                pretrained=False, \
                                                cr=cr, \
                                                dsize=dsize, \
                                                ddepth=ddepth)
else:
    raise NotImplementedError

try:
    start_epoch = mgr.load_weights(model, WEIGHTS_PATH + 'latest.pth')
    #load_weights(model, WEIGHTS_PATH+'latest_5d.pt')
    print("weights loaded")
except:
    #model.apply(weights_init)
    #os.makedirs(WEIGHTS_PATH, exist_ok=True) 
    print("no weights found")

torch.cuda.set_device(device=device_nr)
model.cuda()
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
#optimizer = optim.SGD(net.parameters(), lr=p['lr'], momentum=p['momentum'], weight_decay=p['wd'])
criterion = losses.Dice_Loss()
#criterion = torch.nn.CrossEntropyLoss()

#######################################################

## Initialising logging
logging = log.Log(exp_name)
start_epoch = 1
logging.start_log(LR, N_EPOCHS)
logging.start_csv()

for epoch in range(1, N_EPOCHS+1):
    since = time.time()
    
    print('-' * 10)
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)

    ### Train ###
    metric = train(model, train_dl, optimizer, criterion, epoch)
    # print metrics to console
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)
    print('Train Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Train Time {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'train')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'train')
    
    ### Test ###
    metric = test(model, val_dl, criterion, epoch) 
    print('-' * 10)
    print('Val Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Total Time {:.0f}m {:.0f}s\n'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'val')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'val')
    
    ### Checkpoint ###    
    mgr.save_weights(model, epoch, metric['loss'], metric['acc_all'], WEIGHTS_PATH)

    ### Adjust Lr ###
    mgr.adjust_learning_rate(LR, LR_DECAY, optimizer, epoch, DECAY_EVERY_N_EPOCHS)
# Out:
# 42716
# 29908
# 4268
# 8540
# Constructing DeepLabv3+ model...
# Number of classes: 4
# Output stride: 16
# Number of Input Channels: 7
# loading weights 'weights/deeplab_std_resnet_cr64/latest.pth'
# loaded weights (lastEpoch 20, loss 0.14638642966747284, error 0.8816577196121216)
# weights loaded
# ----------
# Epoch 1/25
# ----------
# Step: 100  Loss: 0.1526  Acc all: 0.8759  Acc mean: 0.8452  IoU: 0.7539  Dice: 0.8474
# Step: 200  Loss: 0.1715  Acc all: 0.8779  Acc mean: 0.8500  IoU: 0.7258  Dice: 0.8285
# Step: 300  Loss: 0.1241  Acc all: 0.8988  Acc mean: 0.8747  IoU: 0.7911  Dice: 0.8759
# Step: 400  Loss: 0.1599  Acc all: 0.8637  Acc mean: 0.8386  IoU: 0.7304  Dice: 0.8401
# Epoch 1/25
# ----------
# Train Loss: 0.1536  Acc all: 0.8724  Acc mean: 0.8365  IoU: 0.7493  Dice: 0.8479
# ----------
# Train Time 6m 38s
# ----------
# Val Loss: 0.1569  Acc all: 0.8806  Acc mean: 0.8456  IoU: 0.7571  Dice: 0.8554
# ----------
# Total Time 7m 5s
#
# ----------
# Epoch 2/25
# ----------
# Step: 100  Loss: 0.1815  Acc all: 0.8499  Acc mean: 0.8020  IoU: 0.7094  Dice: 0.8186
# Step: 200  Loss: 0.1435  Acc all: 0.8680  Acc mean: 0.8279  IoU: 0.7586  Dice: 0.8566
# Step: 300  Loss: 0.1084  Acc all: 0.8812  Acc mean: 0.8949  IoU: 0.8141  Dice: 0.8917
# Step: 400  Loss: 0.1146  Acc all: 0.8955  Acc mean: 0.8748  IoU: 0.8036  Dice: 0.8855
# Epoch 2/25
# ----------
# Train Loss: 0.1506  Acc all: 0.8746  Acc mean: 0.8400  IoU: 0.7535  Dice: 0.8509
# ----------
# Train Time 6m 39s
# ----------
# Val Loss: 0.1515  Acc all: 0.8849  Acc mean: 0.8491  IoU: 0.7645  Dice: 0.8608
# ----------
# Total Time 7m 5s
#
# ----------
# Epoch 3/25
# ----------
# Step: 100  Loss: 0.1178  Acc all: 0.8793  Acc mean: 0.8868  IoU: 0.7969  Dice: 0.8823
# Step: 200  Loss: 0.1300  Acc all: 0.9175  Acc mean: 0.8436  IoU: 0.7877  Dice: 0.8700
# Step: 300  Loss: 0.1467  Acc all: 0.8919  Acc mean: 0.8403  IoU: 0.7568  Dice: 0.8534
# Step: 400  Loss: 0.1804  Acc all: 0.8296  Acc mean: 0.7926  IoU: 0.7065  Dice: 0.8197
# Epoch 3/25
# ----------
# Train Loss: 0.1527  Acc all: 0.8730  Acc mean: 0.8383  IoU: 0.7506  Dice: 0.8488
# ----------
# Train Time 6m 41s
# ----------
# Val Loss: 0.1625  Acc all: 0.8805  Acc mean: 0.8457  IoU: 0.7514  Dice: 0.8497
# ----------
# Total Time 7m 8s
#
# ----------
# Epoch 4/25
# ----------
# Step: 100  Loss: 0.1921  Acc all: 0.8222  Acc mean: 0.7750  IoU: 0.6822  Dice: 0.8079
# ----------
# Total Time 7m 13s

# %%
# dsize 512 x 3

# %%
torch.cuda.empty_cache()

nr_classes = 4
nr_channels = 7
exp_name = 'deeplab_std_resnet_dc_512_3'
WEIGHTS_PATH = 'weights/' + exp_name + '/'
N_EPOCHS = 25
start_epoch = 1
backbone = 'resnet'

cr = 48
dsize = 512
ddepth = 3
os = 16

#######################################################

## Creating the dataset
path_dataset = "/home/philipp/Data/dataset_256_df_177.h5"
#path_dataset = "/media/philipp/DATA/dataset/dataset_256_df_0.h5"
dataset = datasets.ForestDataset(path_dataset, ground_truth='ground_truth_std')

if dataset[0][0].shape[1] == 256:
    chunk_size = 1000
else:
    chunk_size = 0

# shuffle and split
train_sampler, val_sampler, test_sampler = dataset.get_sampler(split=split, \
                shuffle_dataset=True, random_seed=399, chunk_size=chunk_size)

# dataloader
train_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=train_sampler, num_workers=num_workers, pin_memory=pin_memory)
val_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=val_sampler, num_workers=num_workers, pin_memory=pin_memory)
test_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=test_sampler, num_workers=num_workers, pin_memory=pin_memory)
print(len(dataset))
print(len(train_sampler.indices))
print(len(val_sampler.indices))
print(len(test_sampler.indices))

#######################################################

# Network definition
if backbone == 'xception':
    model = deeplab_xception.DeepLabv3_plus(nInputChannels=nr_channels, \
                                            n_classes=nr_classes, os=os, pretrained=False)
elif backbone == 'resnet':
    model = deeplab_resnet_hyper.DeepLabv3_plus(nInputChannels=nr_channels, \
                                                n_classes=nr_classes, os=os, \
                                                pretrained=False, \
                                                cr=cr, \
                                                dsize=dsize, \
                                                ddepth=ddepth)
else:
    raise NotImplementedError

try:
    start_epoch = mgr.load_weights(model, WEIGHTS_PATH + 'latest.pth')
    #load_weights(model, WEIGHTS_PATH+'latest_5d.pt')
    print("weights loaded")
except:
    #model.apply(weights_init)
    #os.makedirs(WEIGHTS_PATH, exist_ok=True) 
    print("no weights found")

torch.cuda.set_device(device=device_nr)
model.cuda()
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
#optimizer = optim.SGD(net.parameters(), lr=p['lr'], momentum=p['momentum'], weight_decay=p['wd'])
criterion = losses.Dice_Loss()
#criterion = torch.nn.CrossEntropyLoss()

#######################################################

## Initialising logging
logging = log.Log(exp_name)
start_epoch = 1
logging.start_log(LR, N_EPOCHS)
logging.start_csv()

for epoch in range(1, N_EPOCHS+1):
    since = time.time()
    
    print('-' * 10)
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)

    ### Train ###
    metric = train(model, train_dl, optimizer, criterion, epoch)
    # print metrics to console
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)
    print('Train Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Train Time {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'train')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'train')
    
    ### Test ###
    metric = test(model, val_dl, criterion, epoch) 
    print('-' * 10)
    print('Val Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Total Time {:.0f}m {:.0f}s\n'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'val')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'val')
    
    ### Checkpoint ###    
    mgr.save_weights(model, epoch, metric['loss'], metric['acc_all'], WEIGHTS_PATH)

    ### Adjust Lr ###
    mgr.adjust_learning_rate(LR, LR_DECAY, optimizer, epoch, DECAY_EVERY_N_EPOCHS)
# Out:
# 42716
# 29908
# 4268
# 8540
# Constructing DeepLabv3+ model...
# Number of classes: 4
# Output stride: 16
# Number of Input Channels: 7
# loading weights 'weights/deeplab_std_resnet_dc_512_3/latest.pth'
# Step: 400  Loss: 0.1058  Acc all: 0.8981  Acc mean: 0.8860  IoU: 0.8168  Dice: 0.8942
# Epoch 4/25
# ----------
# Train Loss: 0.1535  Acc all: 0.8721  Acc mean: 0.8365  IoU: 0.7496  Dice: 0.8479
# ----------
# Train Time 8m 27s
# ----------
# Val Loss: 0.1540  Acc all: 0.8756  Acc mean: 0.8533  IoU: 0.7602  Dice: 0.8582
# ----------
# Total Time 8m 59s
#
# ----------
# Epoch 5/25
# ----------
# Step: 100  Loss: 0.2010  Acc all: 0.8500  Acc mean: 0.7649  IoU: 0.6697  Dice: 0.7990
# Step: 200  Loss: 0.1444  Acc all: 0.8934  Acc mean: 0.8467  IoU: 0.7525  Dice: 0.8557
# Step: 300  Loss: 0.1435  Acc all: 0.8922  Acc mean: 0.8308  IoU: 0.7653  Dice: 0.8566
# Step: 400  Loss: 0.1608  Acc all: 0.8492  Acc mean: 0.8235  IoU: 0.7398  Dice: 0.8393
# Epoch 5/25
# ----------
# Train Loss: 0.1507  Acc all: 0.8753  Acc mean: 0.8392  IoU: 0.7532  Dice: 0.8508
# ----------
# Train Time 8m 35s
# ----------
# Val Loss: 0.1620  Acc all: 0.8784  Acc mean: 0.8416  IoU: 0.7519  Dice: 0.8502
# ----------
# Total Time 9m 7s
#
# ----------
# Epoch 6/25
# ----------
# Step: 100  Loss: 0.1162  Acc all: 0.8776  Acc mean: 0.8808  IoU: 0.8025  Dice: 0.8839
# Step: 200  Loss: 0.1262  Acc all: 0.8753  Acc mean: 0.8531  IoU: 0.7841  Dice: 0.8738
# Step: 300  Loss: 0.1598  Acc all: 0.8722  Acc mean: 0.8308  IoU: 0.7312  Dice: 0.8402
# Step: 400  Loss: 0.1719  Acc all: 0.8714  Acc mean: 0.8213  IoU: 0.7304  Dice: 0.8282
# Epoch 6/25
# ----------
# Train Loss: 0.1549  Acc all: 0.8735  Acc mean: 0.8349  IoU: 0.7478  Dice: 0.8466
# ----------
# Train Time 8m 25s
# ----------
# Val Loss: 0.1571  Acc all: 0.8789  Acc mean: 0.8496  IoU: 0.7574  Dice: 0.8551
# ----------
# Total Time 8m 58s
#
# ----------
# Epoch 7/25
# ----------
# Step: 100  Loss: 0.1569  Acc all: 0.8628  Acc mean: 0.8244  IoU: 0.7360  Dice: 0.8431
# Step: 200  Loss: 0.1477  Acc all: 0.8620  Acc mean: 0.8289  IoU: 0.7540  Dice: 0.8524
# Step: 300  Loss: 0.1345  Acc all: 0.9084  Acc mean: 0.8418  IoU: 0.7697  Dice: 0.8655
# Step: 400  Loss: 0.1260  Acc all: 0.9160  Acc mean: 0.8570  IoU: 0.7882  Dice: 0.8740
# Epoch 7/25
# ----------
# Train Loss: 0.1505  Acc all: 0.8758  Acc mean: 0.8403  IoU: 0.7535  Dice: 0.8510
# ----------
# Train Time 8m 27s
# ----------
# Val Loss: 0.1534  Acc all: 0.8860  Acc mean: 0.8382  IoU: 0.7627  Dice: 0.8588
# ----------
# Total Time 8m 60s
#
# ----------
# Epoch 8/25
# ----------
# Train Loss: 0.1509  Acc all: 0.8769  Acc mean: 0.8370  IoU: 0.7534  Dice: 0.8506
# ----------
# Train Time 8m 13s
# ----------
# Val Loss: 0.1625  Acc all: 0.8788  Acc mean: 0.8280  IoU: 0.7515  Dice: 0.8497
# ----------
# Total Time 8m 45s
#
# ----------
# Epoch 12/25
# ----------
# Step: 100  Loss: 0.2238  Acc all: 0.8116  Acc mean: 0.7573  IoU: 0.6473  Dice: 0.7762
# Step: 200  Loss: 0.1384  Acc all: 0.8960  Acc mean: 0.8540  IoU: 0.7631  Dice: 0.8616
# Step: 300  Loss: 0.1684  Acc all: 0.8760  Acc mean: 0.8155  IoU: 0.7294  Dice: 0.8317
# Step: 400  Loss: 0.1969  Acc all: 0.8443  Acc mean: 0.7643  IoU: 0.6818  Dice: 0.8031
# Epoch 12/25
# ----------
# Train Loss: 0.1484  Acc all: 0.8777  Acc mean: 0.8401  IoU: 0.7565  Dice: 0.8531
# ----------
# Train Time 8m 14s
# ----------
# Val Loss: 0.1500  Acc all: 0.8861  Acc mean: 0.8527  IoU: 0.7666  Dice: 0.8622
# ----------
# Total Time 8m 46s
#
# ----------
# Epoch 13/25
# ----------
# Step: 100  Loss: 0.1167  Acc all: 0.9127  Acc mean: 0.8714  IoU: 0.8026  Dice: 0.8833
# Step: 200  Loss: 0.1507  Acc all: 0.8536  Acc mean: 0.8359  IoU: 0.7532  Dice: 0.8493
# Step: 300  Loss: 0.1245  Acc all: 0.8657  Acc mean: 0.8519  IoU: 0.7883  Dice: 0.8755
# Step: 400  Loss: 0.1788  Acc all: 0.8573  Acc mean: 0.7907  IoU: 0.7092  Dice: 0.8213
# Epoch 13/25
# ----------
# Train Loss: 0.1456  Acc all: 0.8802  Acc mean: 0.8447  IoU: 0.7603  Dice: 0.8559
# ----------
# Train Time 8m 14s
# ----------
# Val Loss: 0.1521  Acc all: 0.8851  Acc mean: 0.8477  IoU: 0.7644  Dice: 0.8601
# ----------
# Total Time 8m 46s
#
# ----------
# Epoch 14/25
# ----------
# Step: 100  Loss: 0.1072  Acc all: 0.9171  Acc mean: 0.8651  IoU: 0.8131  Dice: 0.8928
# Step: 200  Loss: 0.1460  Acc all: 0.8584  Acc mean: 0.8186  IoU: 0.7499  Dice: 0.8540
# Step: 300  Loss: 0.1698  Acc all: 0.8529  Acc mean: 0.8083  IoU: 0.7280  Dice: 0.8303
# Step: 400  Loss: 0.1237  Acc all: 0.9030  Acc mean: 0.8606  IoU: 0.7918  Dice: 0.8763
# Epoch 14/25
# ----------
# Train Loss: 0.1450  Acc all: 0.8806  Acc mean: 0.8441  IoU: 0.7613  Dice: 0.8565
# ----------
# Train Time 8m 11s
# ----------
# Val Loss: 0.1526  Acc all: 0.8849  Acc mean: 0.8452  IoU: 0.7635  Dice: 0.8596
# ----------
# Total Time 8m 43s
#
# ----------
# Epoch 15/25
# ----------
# Step: 100  Loss: 0.1610  Acc all: 0.8536  Acc mean: 0.8045  IoU: 0.7288  Dice: 0.8390
# Step: 200  Loss: 0.1502  Acc all: 0.8782  Acc mean: 0.8168  IoU: 0.7464  Dice: 0.8499
# Step: 300  Loss: 0.1655  Acc all: 0.8639  Acc mean: 0.8238  IoU: 0.7303  Dice: 0.8345
# Step: 400  Loss: 0.1565  Acc all: 0.8716  Acc mean: 0.8540  IoU: 0.7370  Dice: 0.8435
# Epoch 15/25
# ----------
# Train Loss: 0.1450  Acc all: 0.8802  Acc mean: 0.8456  IoU: 0.7611  Dice: 0.8565
# ----------
# Train Time 8m 20s
# ----------
# Val Loss: 0.1477  Acc all: 0.8857  Acc mean: 0.8557  IoU: 0.7702  Dice: 0.8645
# ----------
# Total Time 8m 52s
#
# ----------
# Epoch 16/25
# ----------
# Step: 100  Loss: 0.1362  Acc all: 0.8948  Acc mean: 0.8608  IoU: 0.7755  Dice: 0.8638
# Step: 200  Loss: 0.2322  Acc all: 0.8156  Acc mean: 0.7423  IoU: 0.6309  Dice: 0.7678
# Step: 300  Loss: 0.1452  Acc all: 0.8983  Acc mean: 0.8616  IoU: 0.7541  Dice: 0.8548
# Step: 400  Loss: 0.1329  Acc all: 0.8983  Acc mean: 0.8496  IoU: 0.7806  Dice: 0.8671
# Epoch 16/25
# ----------
# Train Loss: 0.1449  Acc all: 0.8811  Acc mean: 0.8445  IoU: 0.7616  Dice: 0.8566
# ----------
# Train Time 8m 16s
# ----------
# Val Loss: 0.1563  Acc all: 0.8836  Acc mean: 0.8393  IoU: 0.7589  Dice: 0.8559
# ----------
# Total Time 8m 48s
#
# ----------
# Epoch 17/25
# ----------
# Step: 100  Loss: 0.1805  Acc all: 0.8335  Acc mean: 0.8323  IoU: 0.7107  Dice: 0.8195
# Step: 200  Loss: 0.1436  Acc all: 0.8768  Acc mean: 0.8500  IoU: 0.7557  Dice: 0.8564
# Step: 300  Loss: 0.1014  Acc all: 0.9069  Acc mean: 0.9045  IoU: 0.8236  Dice: 0.8987
# Step: 400  Loss: 0.1612  Acc all: 0.9059  Acc mean: 0.8739  IoU: 0.7412  Dice: 0.8388
# Epoch 17/25
# ----------
# Train Loss: 0.1430  Acc all: 0.8815  Acc mean: 0.8475  IoU: 0.7637  Dice: 0.8585
# ----------
# Train Time 8m 12s
# ----------
# Val Loss: 0.1530  Acc all: 0.8814  Acc mean: 0.8491  IoU: 0.7626  Dice: 0.8592
# ----------
# Total Time 8m 44s
#
# ----------
# Epoch 18/25
# ----------
# Step: 100  Loss: 0.1715  Acc all: 0.8643  Acc mean: 0.7939  IoU: 0.7258  Dice: 0.8285
# Step: 200  Loss: 0.1711  Acc all: 0.8787  Acc mean: 0.8431  IoU: 0.7244  Dice: 0.8288
# Step: 300  Loss: 0.1273  Acc all: 0.8929  Acc mean: 0.8499  IoU: 0.7821  Dice: 0.8727
# Step: 400  Loss: 0.1136  Acc all: 0.9230  Acc mean: 0.8754  IoU: 0.8027  Dice: 0.8864
# Epoch 18/25
# ----------
# Train Loss: 0.1414  Acc all: 0.8827  Acc mean: 0.8482  IoU: 0.7657  Dice: 0.8601
# ----------
# Train Time 8m 13s
# ----------
# Val Loss: 0.1488  Acc all: 0.8842  Acc mean: 0.8536  IoU: 0.7682  Dice: 0.8634
# ----------
# Total Time 8m 45s
#
# ----------
# Epoch 19/25
# ----------
# Step: 100  Loss: 0.1068  Acc all: 0.9039  Acc mean: 0.8674  IoU: 0.8153  Dice: 0.8933
# Step: 200  Loss: 0.1193  Acc all: 0.8849  Acc mean: 0.8694  IoU: 0.7976  Dice: 0.8807
# Step: 300  Loss: 0.1481  Acc all: 0.8762  Acc mean: 0.8395  IoU: 0.7574  Dice: 0.8519
# Step: 400  Loss: 0.1376  Acc all: 0.8810  Acc mean: 0.8528  IoU: 0.7671  Dice: 0.8624
# Epoch 19/25
# ----------
# Train Loss: 0.1414  Acc all: 0.8837  Acc mean: 0.8483  IoU: 0.7662  Dice: 0.8601
# ----------
# Train Time 8m 14s
# ----------
# Val Loss: 0.1519  Acc all: 0.8826  Acc mean: 0.8536  IoU: 0.7647  Dice: 0.8603
# ----------
# Total Time 8m 46s
#
# ----------
# Epoch 20/25
# ----------
# Step: 100  Loss: 0.1268  Acc all: 0.8738  Acc mean: 0.8594  IoU: 0.7838  Dice: 0.8732
# Step: 200  Loss: 0.1337  Acc all: 0.8941  Acc mean: 0.8562  IoU: 0.7693  Dice: 0.8663
# Step: 300  Loss: 0.1326  Acc all: 0.8796  Acc mean: 0.8491  IoU: 0.7780  Dice: 0.8674
# Step: 400  Loss: 0.1072  Acc all: 0.9248  Acc mean: 0.8992  IoU: 0.8157  Dice: 0.8929
# Epoch 20/25
# ----------
# Train Loss: 0.1389  Acc all: 0.8854  Acc mean: 0.8507  IoU: 0.7694  Dice: 0.8626
# ----------
# Train Time 8m 21s
# ----------
# Val Loss: 0.1490  Acc all: 0.8873  Acc mean: 0.8548  IoU: 0.7681  Dice: 0.8632
# ----------
# Total Time 8m 53s
#
# ----------
# Epoch 21/25
# ----------
# Step: 100  Loss: 0.1213  Acc all: 0.9025  Acc mean: 0.8420  IoU: 0.7849  Dice: 0.8787
# Step: 200  Loss: 0.1224  Acc all: 0.8795  Acc mean: 0.8776  IoU: 0.7932  Dice: 0.8777
# Step: 300  Loss: 0.1068  Acc all: 0.9061  Acc mean: 0.8924  IoU: 0.8157  Dice: 0.8932
# Step: 400  Loss: 0.1534  Acc all: 0.8737  Acc mean: 0.8214  IoU: 0.7524  Dice: 0.8466
# Epoch 21/25
# ----------
# Train Loss: 0.1381  Acc all: 0.8866  Acc mean: 0.8524  IoU: 0.7710  Dice: 0.8634
# ----------
# Train Time 8m 17s
# ----------
# Val Loss: 0.1525  Acc all: 0.8862  Acc mean: 0.8465  IoU: 0.7635  Dice: 0.8597
# ----------
# Total Time 8m 49s
#
# ----------
# Epoch 22/25
# ----------
# Step: 100  Loss: 0.0944  Acc all: 0.9107  Acc mean: 0.9177  IoU: 0.8346  Dice: 0.9056
# Step: 200  Loss: 0.1260  Acc all: 0.8826  Acc mean: 0.8466  IoU: 0.7794  Dice: 0.8741
# Step: 300  Loss: 0.1269  Acc all: 0.8868  Acc mean: 0.8746  IoU: 0.7861  Dice: 0.8731
# Step: 400  Loss: 0.1196  Acc all: 0.8964  Acc mean: 0.8541  IoU: 0.7972  Dice: 0.8804
# Epoch 22/25
# ----------
# Train Loss: 0.1362  Acc all: 0.8869  Acc mean: 0.8536  IoU: 0.7732  Dice: 0.8653
# ----------
# Train Time 8m 21s
# ----------
# Val Loss: 0.1477  Acc all: 0.8865  Acc mean: 0.8522  IoU: 0.7700  Dice: 0.8645
# ----------
# Total Time 8m 52s
#
# ----------
# Epoch 23/25
# ----------
# Step: 100  Loss: 0.1156  Acc all: 0.8969  Acc mean: 0.8887  IoU: 0.8035  Dice: 0.8844
# Step: 200  Loss: 0.1371  Acc all: 0.9042  Acc mean: 0.8589  IoU: 0.7747  Dice: 0.8630
# Step: 300  Loss: 0.0801  Acc all: 0.9355  Acc mean: 0.9173  IoU: 0.8573  Dice: 0.9199
# Step: 400  Loss: 0.1311  Acc all: 0.9194  Acc mean: 0.8815  IoU: 0.7853  Dice: 0.8690
# Epoch 23/25
# ----------
# Train Loss: 0.1346  Acc all: 0.8891  Acc mean: 0.8542  IoU: 0.7757  Dice: 0.8669
# ----------
# Train Time 8m 24s
# ----------
# Val Loss: 0.1490  Acc all: 0.8807  Acc mean: 0.8591  IoU: 0.7677  Dice: 0.8633
# ----------
# Total Time 8m 55s
#
# ----------
# Epoch 24/25
# ----------
# Step: 100  Loss: 0.1484  Acc all: 0.8694  Acc mean: 0.8406  IoU: 0.7479  Dice: 0.8516
# Step: 200  Loss: 0.1412  Acc all: 0.8864  Acc mean: 0.8394  IoU: 0.7672  Dice: 0.8589
# Step: 300  Loss: 0.1005  Acc all: 0.9002  Acc mean: 0.9019  IoU: 0.8251  Dice: 0.8995
# Step: 400  Loss: 0.1474  Acc all: 0.8541  Acc mean: 0.8641  IoU: 0.7487  Dice: 0.8525
# Epoch 24/25
# ----------
# Train Loss: 0.1344  Acc all: 0.8883  Acc mean: 0.8553  IoU: 0.7758  Dice: 0.8671
# ----------
# Train Time 8m 17s
# ----------
# Val Loss: 0.1526  Acc all: 0.8851  Acc mean: 0.8424  IoU: 0.7629  Dice: 0.8596
# ----------
# Total Time 8m 49s
#
# ----------
# Epoch 25/25
# ----------
# Step: 100  Loss: 0.0880  Acc all: 0.9141  Acc mean: 0.9092  IoU: 0.8446  Dice: 0.9120
# Step: 200  Loss: 0.0987  Acc all: 0.8981  Acc mean: 0.8838  IoU: 0.8266  Dice: 0.9013
# Step: 300  Loss: 0.1127  Acc all: 0.8841  Acc mean: 0.8962  IoU: 0.8070  Dice: 0.8873
# Step: 400  Loss: 0.1302  Acc all: 0.8985  Acc mean: 0.8535  IoU: 0.7793  Dice: 0.8698
# Epoch 25/25
# ----------
# Train Loss: 0.1332  Acc all: 0.8910  Acc mean: 0.8563  IoU: 0.7778  Dice: 0.8683
# ----------
# Train Time 8m 25s
# ----------
# Val Loss: 0.1511  Acc all: 0.8835  Acc mean: 0.8488  IoU: 0.7647  Dice: 0.8611
# ----------
# Total Time 8m 56s

# %%
# dsize 1024 x 3

# %%
torch.cuda.empty_cache()

# %%
torch.cuda.empty_cache()

batch_size = 56
nr_classes = 4
nr_channels = 7
exp_name = 'deeplab_std_resnet_dc_1024_3'
WEIGHTS_PATH = 'weights/' + exp_name + '/'
N_EPOCHS = 25
start_epoch = 1
backbone = 'resnet'

cr = 48
dsize = 1024
ddepth = 3
os = 16

#######################################################

## Creating the dataset
path_dataset = "/home/philipp/Data/dataset_256_df_177.h5"
#path_dataset = "/media/philipp/DATA/dataset/dataset_256_df_0.h5"
dataset = datasets.ForestDataset(path_dataset, ground_truth='ground_truth_std')

if dataset[0][0].shape[1] == 256:
    chunk_size = 1000
else:
    chunk_size = 0

# shuffle and split
train_sampler, val_sampler, test_sampler = dataset.get_sampler(split=split, \
                shuffle_dataset=True, random_seed=399, chunk_size=chunk_size)

# dataloader
train_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=train_sampler, num_workers=num_workers, pin_memory=pin_memory)
val_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=val_sampler, num_workers=num_workers, pin_memory=pin_memory)
test_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=test_sampler, num_workers=num_workers, pin_memory=pin_memory)
print(len(dataset))
print(len(train_sampler.indices))
print(len(val_sampler.indices))
print(len(test_sampler.indices))

#######################################################

# Network definition
if backbone == 'xception':
    model = deeplab_xception.DeepLabv3_plus(nInputChannels=nr_channels, \
                                            n_classes=nr_classes, os=os, pretrained=False)
elif backbone == 'resnet':
    model = deeplab_resnet_hyper.DeepLabv3_plus(nInputChannels=nr_channels, \
                                                n_classes=nr_classes, os=os, \
                                                pretrained=False, \
                                                cr=cr, \
                                                dsize=dsize, \
                                                ddepth=ddepth)
else:
    raise NotImplementedError

try:
    start_epoch = mgr.load_weights(model, WEIGHTS_PATH + 'latest.pth')
    #load_weights(model, WEIGHTS_PATH+'latest_5d.pt')
    print("weights loaded")
except:
    #model.apply(weights_init)
    #os.makedirs(WEIGHTS_PATH, exist_ok=True) 
    print("no weights found")

torch.cuda.set_device(device=device_nr)
model.cuda()
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
#optimizer = optim.SGD(net.parameters(), lr=p['lr'], momentum=p['momentum'], weight_decay=p['wd'])
criterion = losses.Dice_Loss()
#criterion = torch.nn.CrossEntropyLoss()

#######################################################

## Initialising logging
logging = log.Log(exp_name)
start_epoch = 1
logging.start_log(LR, N_EPOCHS)
logging.start_csv()

for epoch in range(1, N_EPOCHS+1):
    since = time.time()
    
    print('-' * 10)
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)

    ### Train ###
    metric = train(model, train_dl, optimizer, criterion, epoch)
    # print metrics to console
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)
    print('Train Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Train Time {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'train')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'train')
    
    ### Test ###
    metric = test(model, val_dl, criterion, epoch) 
    print('-' * 10)
    print('Val Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Total Time {:.0f}m {:.0f}s\n'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'val')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'val')
    
    ### Checkpoint ###    
    mgr.save_weights(model, epoch, metric['loss'], metric['acc_all'], WEIGHTS_PATH)

    ### Adjust Lr ###
    mgr.adjust_learning_rate(LR, LR_DECAY, optimizer, epoch, DECAY_EVERY_N_EPOCHS)
# Out:
# 42716
# 29908
# 4268
# 8540
# Constructing DeepLabv3+ model...
# Number of classes: 4
# Output stride: 16
# Number of Input Channels: 7
# loading weights 'weights/deeplab_std_resnet_dc_1024_3/latest.pth'
# loaded weights (lastEpoch 17, loss 0.1500854194164276, error 0.8804186582565308)
# weights loaded
# ----------
# Epoch 1/25
# ----------
# /home/philipp/Software/minconda3/envs/pytorch/lib/python3.8/site-packages/torch/nn/functional.py:3325: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %%
# dsize 512 x 4

# %%
torch.cuda.empty_cache()

batch_size = 72
nr_classes = 4
nr_channels = 7
exp_name = 'deeplab_std_resnet_dc_512_4'
WEIGHTS_PATH = 'weights/' + exp_name + '/'
N_EPOCHS = 25
start_epoch = 1
backbone = 'resnet'

cr = 48
dsize = 512
ddepth = 4
os = 16

#######################################################

## Creating the dataset
path_dataset = "/home/philipp/Data/dataset_256_df_177.h5"
#path_dataset = "/media/philipp/DATA/dataset/dataset_256_df_0.h5"
dataset = datasets.ForestDataset(path_dataset, ground_truth='ground_truth_std')

if dataset[0][0].shape[1] == 256:
    chunk_size = 1000
else:
    chunk_size = 0

# shuffle and split
train_sampler, val_sampler, test_sampler = dataset.get_sampler(split=split, \
                shuffle_dataset=True, random_seed=399, chunk_size=chunk_size)

# dataloader
train_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=train_sampler, num_workers=num_workers, pin_memory=pin_memory)
val_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=val_sampler, num_workers=num_workers, pin_memory=pin_memory)
test_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=test_sampler, num_workers=num_workers, pin_memory=pin_memory)
print(len(dataset))
print(len(train_sampler.indices))
print(len(val_sampler.indices))
print(len(test_sampler.indices))

#######################################################

# Network definition
if backbone == 'xception':
    model = deeplab_xception.DeepLabv3_plus(nInputChannels=nr_channels, \
                                            n_classes=nr_classes, os=os, pretrained=False)
elif backbone == 'resnet':
    model = deeplab_resnet_hyper.DeepLabv3_plus(nInputChannels=nr_channels, \
                                                n_classes=nr_classes, os=os, \
                                                pretrained=False, \
                                                cr=cr, \
                                                dsize=dsize, \
                                                ddepth=ddepth)
else:
    raise NotImplementedError

try:
    start_epoch = mgr.load_weights(model, WEIGHTS_PATH + 'latest.pth')
    #load_weights(model, WEIGHTS_PATH+'latest_5d.pt')
    print("weights loaded")
except:
    #model.apply(weights_init)
    #os.makedirs(WEIGHTS_PATH, exist_ok=True) 
    print("no weights found")

torch.cuda.set_device(device=device_nr)
model.cuda()
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
#optimizer = optim.SGD(net.parameters(), lr=p['lr'], momentum=p['momentum'], weight_decay=p['wd'])
criterion = losses.Dice_Loss()
#criterion = torch.nn.CrossEntropyLoss()

#######################################################

## Initialising logging
logging = log.Log(exp_name)
start_epoch = 1
logging.start_log(LR, N_EPOCHS)
logging.start_csv()

for epoch in range(1, N_EPOCHS+1):
    since = time.time()
    
    print('-' * 10)
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)

    ### Train ###
    metric = train(model, train_dl, optimizer, criterion, epoch)
    # print metrics to console
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)
    print('Train Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Train Time {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'train')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'train')
    
    ### Test ###
    metric = test(model, val_dl, criterion, epoch) 
    print('-' * 10)
    print('Val Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Total Time {:.0f}m {:.0f}s\n'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'val')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'val')
    
    ### Checkpoint ###    
    mgr.save_weights(model, epoch, metric['loss'], metric['acc_all'], WEIGHTS_PATH)

    ### Adjust Lr ###
    mgr.adjust_learning_rate(LR, LR_DECAY, optimizer, epoch, DECAY_EVERY_N_EPOCHS)

# %%
# dsize 512 x 5

# %%
torch.cuda.empty_cache()

nr_classes = 4
nr_channels = 7
exp_name = 'deeplab_std_resnet_dc_512_5'
WEIGHTS_PATH = 'weights/' + exp_name + '/'
N_EPOCHS = 25
start_epoch = 1
backbone = 'resnet'

cr = 48
dsize = 512
ddepth = 5
os = 16

#######################################################

## Creating the dataset
path_dataset = "/home/philipp/Data/dataset_256_df_177.h5"
#path_dataset = "/media/philipp/DATA/dataset/dataset_256_df_0.h5"
dataset = datasets.ForestDataset(path_dataset, ground_truth='ground_truth_std')

if dataset[0][0].shape[1] == 256:
    chunk_size = 1000
else:
    chunk_size = 0

# shuffle and split
train_sampler, val_sampler, test_sampler = dataset.get_sampler(split=split, \
                shuffle_dataset=True, random_seed=399, chunk_size=chunk_size)

# dataloader
train_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=train_sampler, num_workers=num_workers, pin_memory=pin_memory)
val_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=val_sampler, num_workers=num_workers, pin_memory=pin_memory)
test_dl = torch.utils.data.DataLoader(dataset, batch_size=batch_size, \
                                sampler=test_sampler, num_workers=num_workers, pin_memory=pin_memory)
print(len(dataset))
print(len(train_sampler.indices))
print(len(val_sampler.indices))
print(len(test_sampler.indices))

#######################################################

# Network definition
if backbone == 'xception':
    model = deeplab_xception.DeepLabv3_plus(nInputChannels=nr_channels, \
                                            n_classes=nr_classes, os=os, pretrained=False)
elif backbone == 'resnet':
    model = deeplab_resnet_hyper.DeepLabv3_plus(nInputChannels=nr_channels, \
                                                n_classes=nr_classes, os=os, \
                                                pretrained=False, \
                                                cr=cr, \
                                                dsize=dsize, \
                                                ddepth=ddepth)
else:
    raise NotImplementedError

try:
    start_epoch = mgr.load_weights(model, WEIGHTS_PATH + 'latest.pth')
    #load_weights(model, WEIGHTS_PATH+'latest_5d.pt')
    print("weights loaded")
except:
    #model.apply(weights_init)
    #os.makedirs(WEIGHTS_PATH, exist_ok=True) 
    print("no weights found")

torch.cuda.set_device(device=device_nr)
model.cuda()
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
#optimizer = optim.SGD(net.parameters(), lr=p['lr'], momentum=p['momentum'], weight_decay=p['wd'])
criterion = losses.Dice_Loss()
#criterion = torch.nn.CrossEntropyLoss()

#######################################################

## Initialising logging
logging = log.Log(exp_name)
start_epoch = 1
logging.start_log(LR, N_EPOCHS)
logging.start_csv()

for epoch in range(1, N_EPOCHS+1):
    since = time.time()
    
    print('-' * 10)
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)

    ### Train ###
    metric = train(model, train_dl, optimizer, criterion, epoch)
    # print metrics to console
    print('Epoch {}/{}'.format(epoch, N_EPOCHS))
    print('-' * 10)
    print('Train Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Train Time {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'train')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'train')
    
    ### Test ###
    metric = test(model, val_dl, criterion, epoch) 
    print('-' * 10)
    print('Val Loss: {:.4f}  Acc all: {:.4f}  Acc mean: {:.4f}  IoU: {:.4f}  Dice: {:.4f}'\
          .format(metric['loss'], metric['acc_all'], metric['acc_mean'], metric['jacc'], metric['dice']))
    print('-' * 10)
    time_elapsed = time.time() - since  
    print('Total Time {:.0f}m {:.0f}s\n'.format(time_elapsed // 60, time_elapsed % 60))
    logging.add_log(epoch, metric, time_elapsed // 60, 'val')
    logging.add_csv(epoch, metric, time_elapsed // 60, 'val')
    
    ### Checkpoint ###    
    mgr.save_weights(model, epoch, metric['loss'], metric['acc_all'], WEIGHTS_PATH)

    ### Adjust Lr ###
    mgr.adjust_learning_rate(LR, LR_DECAY, optimizer, epoch, DECAY_EVERY_N_EPOCHS)
